# %% [markdown]
# ### Imports

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# ### Load Data

# %%
base_dir = Path.cwd()
out_dir = base_dir / "results"
df = pd.read_csv(base_dir/"final.csv")
df.head()
# Out:
#    Unnamed: 0                                          File Name  \
# 0           4  sliced_bce376c8-06f6-4242-a32b-9488f7f4eb82_wx...
# 1           6  sliced_218349a8-16e2-4bcd-9c9a-690bc5152441_wx...
# 2           7  sliced_ecd45ec0-57dd-4b73-a0eb-52a1d54d5c17_wx...
# 3           9  sliced_269ffccf-de74-4303-8d2f-0b737598d9f9_wx...
# 4          10  sliced_27f4dc0c-6231-4650-a00e-9ccc4e942c89_wx...
#
#       Sample ID    Case ID Tumor Descriptor Project ID  tumor_count  \
# 0  C3N-03453-01  C3N-03453          Primary    CPTAC-3       577306
# 1  C3L-01232-03  C3L-01232          Primary    CPTAC-3        15427
# 2  C3N-03088-01  C3N-03088          Primary    CPTAC-3         8718
# 3  C3L-03728-01  C3L-03728          Primary    CPTAC-3        13257
# 4  C3N-04693-01  C3N-04693          Primary    CPTAC-3        28833
#
#    normal_count  Ratio(Tumor Count/Blood Count)
# 0         12405                       46.538170
# 1         15639                        0.986444
# 2         10327                        0.844195
# 3         11893                        1.114689
# 4         13766                        2.094508

# %% [markdown]
# ### Main

# %%
df = df.iloc[:,1:].copy()
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df = df[df['Ratio(Tumor Count/Blood Count)']!=0]
df = df.sort_values('Ratio(Tumor Count/Blood Count)',ascending=False).copy()
df.reset_index(drop=True,inplace=True)

# %%
df.value_counts('Project ID')
# Out:
# Project ID
# CPTAC-3    195
# Name: count, dtype: int64

# %%
df.to_csv(out_dir/"CCT6A.csv",index=False)

# %%
types = df['Project ID'].value_counts().index.to_list()

# %%
writer = pd.ExcelWriter(out_dir / f'Mien1.xlsx', engine='xlsxwriter')


for i in types:
    temp = df[df['Project ID']==i].copy()
    temp.reset_index(drop=True,inplace=True)
    temp.to_excel(writer, sheet_name=i, index=False)

writer.close()

# %%
df
# Out:
#                                              File Name  \
# 0    sliced_bce376c8-06f6-4242-a32b-9488f7f4eb82_wx...
# 1    sliced_94dc4f39-5f41-450e-bc88-b5efb574ab4b_wx...
# 2    sliced_3b2c4984-e1ca-4748-bb09-e62be4918bae_gd...
# 3    sliced_425c32f8-8376-440c-9f44-e53deebcf65c_wx...
# 4    sliced_5edb7cc0-ff25-4b38-b386-cb8815496b27_wx...
# ..                                                 ...
# 190  sliced_cf8b37ba-cabe-4e3b-9c0d-086725757e17_wx...
# 191  sliced_e2e5dd96-5ce1-42d5-befd-7ba28a60290a_wx...
# 192  sliced_bd96ecbf-17b9-4dac-8090-05191cf90ee5_wx...
# 193  sliced_98a99ed8-3078-434b-8734-672dfba4299f_wx...
# 194  sliced_7258c996-c299-4b53-93bf-85df20425431_wx...
#
#                       Sample ID    Case ID Tumor Descriptor Project ID  \
# 0                  C3N-03453-01  C3N-03453          Primary    CPTAC-3
# 1                       1105252    C761370          Primary    CPTAC-3
# 2                  C3L-01327-01  C3L-01327          Primary    CPTAC-3
# 3                  C3L-02970-03  C3L-02970          Primary    CPTAC-3
# 4    C3L-01155-02, C3L-01155-01  C3L-01155          Primary    CPTAC-3
# ..                          ...        ...              ...        ...
# 190                C3N-01367-02  C3N-01367          Primary    CPTAC-3
# 191                C3N-01851-01  C3N-01851          Primary    CPTAC-3
# 192                C3N-02183-01  C3N-02183          Primary    CPTAC-3
# 193                C3N-02185-01  C3N-02185          Primary    CPTAC-3
# 194                C3L-02955-01  C3L-02955          Primary    CPTAC-3
#
#      tumor_count  normal_count  Ratio(Tumor Count/Blood Count)
# 0         577306         12405                       46.538170
# 1         300891         11411                       26.368504
# 2         212887         10774                       19.759328
# 3         175235          9723                       18.022730
# 4         132658          9736                       13.625514
# ..           ...           ...                             ...
# 190        13250         20891                        0.634244
# 191         7317         11815                        0.619298
# 192         9207         14953                        0.615729
# 193         9184         16130                        0.569374
# 194         8515         17441                        0.488217
#
# [195 rows x 8 columns]
